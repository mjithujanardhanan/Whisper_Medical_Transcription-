# %%
from transformers import pipeline
import gradio as gr

pipe = pipeline(model="jithuj12344321/whisper-small-en")  # change to "your-username/the-name-you-picked"

result=pipe('/content/1249120_1853182_11719913.wav')
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:496: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(

# %%
print(result)
# Out:
# {'text': "I can't move my head up and down."}

# %%
result2=pipe('/content/Recording.wav')
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:496: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(

# %%
print(result2)
# Out:
# {'text': 'i have pain in my knees'}

# %%
result3=pipe('/content/Recording (2).wav')
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:496: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(

# %%
print(result3)
# Out:
# {'text': 'I have been experiencing severe pain in my lower back for the past two weeks.  The pain started after I lifted a heavy object at work.'}

# %%
result4=pipe('/content/larger_voice_recording.wav')
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:496: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(

# %%
print(result4)
# Out:
# {'text': "I've been experiencing severe pain in my lower back for the past two weeks. The pain started after I lifted a heavy object at work. It feels like a sharp stabbing pain and it worsens when I bend or lift something. I've also noticed that the pain radiates down to my right leg and sometimes I feel numbness or tingling in my toes.I have tried rusting and taking over the counter, pain relievers, but that relief is temporary. I am concerned it might be something more serious, like a herniated disc or nerve compression."}
